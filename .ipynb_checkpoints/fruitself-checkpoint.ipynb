# %%
tf.keras.layers.Conv2D(32,3,activation='relu'),
                tf.keras.layers.MaxPooling2D(),
# Out:
# Found 1932 files belonging to 14 classes.
# Using 1546 files for training.

# %%
import tensorflow as tf
import numpy as np 
import matplotlib.pyplot as plt 
import pickle


class Training:
    def __init__(self):
        self.datasetPath = 'D:\\Datasets\\archive'
        self.imgShape = (64,64)
        
    def getData(self,subset='training'):
        try:
            trainingData = tf.keras.utils.image_dataset_from_directory(
                self.datasetPath,
                validation_split=0.2,
                subset=subset,
                image_size= self.imgShape,
                seed = 58,
                batch_size = 32
            )
            return trainingData
        except Exception as e:
            raise e
    
    def visualizeData(self):
        try:
            trainingData = self.getData()
            classNames = trainingData.class_names
            for images,lables in trainingData.take(1):
                plt.figure(figsize=(10,10))
                for i in range(18):
                    plt.subplot(6,3,i+1)
                    plt.imshow(images[i].numpy().astype('uint32'))
                    plt.title(classNames[lables[i].numpy().astype('uint8')])
        except Exception as e:
            raise e
                  
    def createModel(self):
        try:
            trainingData = self.getData();
            valData = self.getData(subset='validation')
            CLASSES = len(valData.class_names)
            LAYERS = [
                tf.keras.layers.Rescaling(1./255),
                tf.keras.layers.Conv2D(32,3,activation='relu'),
                tf.keras.layers.MaxPooling2D(),
                tf.keras.layers.Conv2D(32,3,activation='relu'),
                tf.keras.layers.MaxPooling2D(),
                tf.keras.layers.Conv2D(32,3,activation='relu'),
                tf.keras.layers.MaxPooling2D(),
                tf.keras.layers.Flatten(),
                tf.keras.layers.Dense(256,activation='relu'),
                tf.keras.layers.Dense(128,activation='relu'),
                tf.keras.layers.Dense(64,activation='relu'),
                tf.keras.layers.Dense(CLASSES)
            ]
            
            model = tf.keras.models.Sequential(LAYERS)
            model.compile(
                optimizer='adam',
                metrics=['accuracy'],
                loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
            )
            
            hist=model.fit(
                trainingData,
                epochs=100,
                validation_data=valData
            )
            model.save("fruitLife.h5")
        except Exception as e:
            raise e
            
    def modelValidation(self):
        try:
            valData = self.getData(subset="validation")
            classNames = valData.class_names
            plt.figure(figsize=(15,30))
            model = tf.keras.models.load_model('fruitLife.h5')
            for images,lables in valData.take(1):
                for i in range(18):
                    plt.subplot(6,3,i+1)
                    img = np.reshape(images[i],(1,64,64,3))
                    probablity = model.predict(img)
                    yPred = classNames[np.argmax(probablity)]
                    yActual = classNames[lables[i].numpy().astype('uint32')]
                    plt.imshow(images[i].numpy().astype('uint8'))
                    plt.title(f"Model Evaluation")
                    plt.xlabel(f"Actual:{yActual}")
                    plt.ylabel(f"Predicted:{yPred}")
                    
        except Exception as e:
            raise e
                    
                
              
obj = Training()
obj.createModel()
# Out:
# Found 1932 files belonging to 14 classes.
# Using 1546 files for training.
# Found 1932 files belonging to 14 classes.
# Using 386 files for validation.
# Epoch 1/100
# 49/49 [==============================] - 21s 328ms/step - loss: 2.0824 - accuracy: 0.3279 - val_loss: 1.5403 - val_accuracy: 0.4482
# Epoch 2/100
# 49/49 [==============================] - 10s 185ms/step - loss: 1.1381 - accuracy: 0.5653 - val_loss: 0.9360 - val_accuracy: 0.6425
# Epoch 3/100
# 49/49 [==============================] - 10s 185ms/step - loss: 0.8357 - accuracy: 0.6410 - val_loss: 0.7022 - val_accuracy: 0.6969
# Epoch 4/100
# 49/49 [==============================] - 9s 182ms/step - loss: 0.7059 - accuracy: 0.7031 - val_loss: 0.6432 - val_accuracy: 0.7642
# Epoch 5/100
# 49/49 [==============================] - 9s 183ms/step - loss: 0.6066 - accuracy: 0.7335 - val_loss: 0.4905 - val_accuracy: 0.8057
# Epoch 6/100
# 49/49 [==============================] - 9s 181ms/step - loss: 0.5817 - accuracy: 0.7432 - val_loss: 0.4888 - val_accuracy: 0.7824
# Epoch 7/100
# 49/49 [==============================] - 9s 182ms/step - loss: 0.5071 - accuracy: 0.7937 - val_loss: 0.4725 - val_accuracy: 0.7927
# Epoch 8/100
#  3/49 [>.............................] - ETA: 9s - loss: 0.4822 - accuracy: 0.8021

# %%
obj.modelValidation()
# Out:
# Found 1932 files belonging to 14 classes.
# Using 386 files for validation.
